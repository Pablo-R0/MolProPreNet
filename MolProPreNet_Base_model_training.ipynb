# %% [markdown]
# This notebook is a Work in Progress summary of the workflow and its tools

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
import os
import numpy as np
import torch

# %%
from tools import smiles_to_graph

# %%
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'cpu'

# %% [markdown]
# Use PolyMetriX for datasets (with features)
# https://github.com/lamalab-org/PolyMetriX

# %%
# Import necessary modules
from polymetrix.datasets import CuratedGlassTempDataset

# Load the dataset
dataset = CuratedGlassTempDataset()
print("Available features:", dataset.available_features)
print("Available labels:", dataset.available_labels)
print("Available metadata:", dataset.meta_info)
# Out:
# Available features: ['sidechainlevel.features.num_atoms_sidechainfeaturizer_sum', 'sidechainlevel.features.num_atoms_sidechainfeaturizer_mean', 'sidechainlevel.features.num_atoms_sidechainfeaturizer_max', 'sidechainlevel.features.num_atoms_sidechainfeaturizer_min', 'sidechainlevel.features.numsidechainfeaturizer', 'sidechainlevel.features.sidechainlength_to_star_attachment_distance_ratio_mean', 'sidechainlevel.features.sidechainlength_to_star_attachment_distance_ratio_min', 'sidechainlevel.features.sidechainlength_to_star_attachment_distance_ratio_max', 'sidechainlevel.features.sidechainlength_to_star_attachment_distance_ratio_sum', 'sidechainlevel.features.star_to_sidechain_min_distance_mean', 'sidechainlevel.features.star_to_sidechain_min_distance_min', 'sidechainlevel.features.star_to_sidechain_min_distance_max', 'sidechainlevel.features.star_to_sidechain_min_distance_sum', 'sidechainlevel.features.num_diverse_sidechains', 'sidechainlevel.features.balaban_j_index_sidechainfeaturizer_sum', 'sidechainlevel.features.num_hbond_donors_sidechainfeaturizer_sum', 'sidechainlevel.features.num_hbond_acceptors_sidechainfeaturizer_sum', 'sidechainlevel.features.num_rotatable_bonds_sidechainfeaturizer_sum', 'sidechainlevel.features.num_rings_sidechainfeaturizer_sum', 'sidechainlevel.features.num_non_aromatic_rings_sidechainfeaturizer_sum', 'sidechainlevel.features.num_aromatic_rings_sidechainfeaturizer_sum', 'sidechainlevel.features.topological_surface_area_sidechainfeaturizer_sum', 'sidechainlevel.features.fraction_bicyclic_rings_sidechainfeaturizer_sum', 'sidechainlevel.features.num_aliphatic_heterocycles_sidechainfeaturizer_sum', 'sidechainlevel.features.slogp_vsa1_sidechainfeaturizer_sum', 'sidechainlevel.features.molecular_weight_sidechainfeaturizer_sum', 'sidechainlevel.features.sp3_carbon_count_sidechainfeaturizer_sum', 'sidechainlevel.features.sp2_carbon_count_sidechainfeaturizer_sum', 'sidechainlevel.features.max_estate_index_sidechainfeaturizer_sum', 'sidechainlevel.features.smr_vsa5_sidechainfeaturizer_sum', 'sidechainlevel.features.fp_density_morgan1_sidechainfeaturizer_sum', 'sidechainlevel.features.total_halogens_sidechainfeaturizer_sum', 'sidechainlevel.features.fluorine_count_sidechainfeaturizer_sum', 'sidechainlevel.features.chlorine_count_sidechainfeaturizer_sum', 'sidechainlevel.features.bromine_count_sidechainfeaturizer_sum', 'sidechainlevel.features.single_bonds_sidechainfeaturizer_sum', 'sidechainlevel.features.double_bonds_sidechainfeaturizer_sum', 'sidechainlevel.features.triple_bonds_sidechainfeaturizer_sum', 'sidechainlevel.features.bridging_rings_count_sidechainfeaturizer_sum', 'sidechainlevel.features.max_ring_size_sidechainfeaturizer_sum', 'sidechainlevel.features.heteroatom_density_sidechainfeaturizer_sum', 'sidechainlevel.features.heteroatom_count_sidechainfeaturizer_sum', 'backbonelevel.features.num_atoms_sum_backbonefeaturizer', 'backbonelevel.features.numbackbonefeaturizer', 'backbonelevel.features.balaban_j_index_sum_backbonefeaturizer', 'backbonelevel.features.num_hbond_donors_sum_backbonefeaturizer', 'backbonelevel.features.num_hbond_acceptors_sum_backbonefeaturizer', 'backbonelevel.features.num_rotatable_bonds_sum_backbonefeaturizer', 'backbonelevel.features.num_rings_sum_backbonefeaturizer', 'backbonelevel.features.num_non_aromatic_rings_sum_backbonefeaturizer', 'backbonelevel.features.num_aromatic_rings_sum_backbonefeaturizer', 'backbonelevel.features.topological_surface_area_sum_backbonefeaturizer', 'backbonelevel.features.fraction_bicyclic_rings_sum_backbonefeaturizer', 'backbonelevel.features.num_aliphatic_heterocycles_sum_backbonefeaturizer', 'backbonelevel.features.slogp_vsa1_sum_backbonefeaturizer', 'backbonelevel.features.molecular_weight_sum_backbonefeaturizer', 'backbonelevel.features.sp3_carbon_count_sum_backbonefeaturizer', 'backbonelevel.features.sp2_carbon_count_sum_backbonefeaturizer', 'backbonelevel.features.max_estate_index_sum_backbonefeaturizer', 'backbonelevel.features.smr_vsa5_ ...
# Available labels: ['labels.Exp_Tg(K)']
# Available metadata: ['meta.polymer', 'meta.source', 'meta.tg_range', 'meta.tg_values', 'meta.num_of_points', 'meta.std', 'meta.reliability', 'meta.polymer_class']

# %%
psmiles = dataset.psmiles[0]
pol = Chem.MolFromSmiles(psmiles)
pol

# %% [markdown]
# Transform a SMILES to a PyG graph

# %%
data = smiles_to_graph(Chem.MolToSmiles(pol))
print(data.x.shape, data.edge_index.shape, len(pol.GetAtoms()),len(pol.GetBonds()))
# Out:
# torch.Size([13, 9]) torch.Size([2, 26]) 13 13

# %%
from torch_geometric.loader import DataLoader
from torch.utils.data import random_split

list_datas = []
for psmiles, exp_tg in zip(dataset.psmiles, dataset._labels):
    data = smiles_to_graph(psmiles)
    data.y = torch.tensor(exp_tg,dtype=torch.float32)
    data.to(device)
    list_datas.append(data)

N = len(list_datas)
train_size = int(0.8*N)
val_size = int(0.1*N)
test_size = N - train_size - val_size
train,val,test = random_split(list_datas,[train_size, val_size, test_size])

train_loader = DataLoader(train,batch_size=32,shuffle=True)
val_loader = DataLoader(val,batch_size=32)
test_loader = DataLoader(test,batch_size=32)

# %%
import torch
from torch import Tensor
from torch_geometric.nn import GCNConv, global_mean_pool, Linear
from torch.nn import ReLU


class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
        self.head = Linear(out_channels,1)

    def forward(self, x: Tensor, edge_index: Tensor, batch: Tensor) -> Tensor:
        # x: Node feature matrix of shape [num_nodes, in_channels]
        # edge_index: Graph connectivity matrix of shape [2, num_edges]
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index).relu()
        x = global_mean_pool(x, batch)
        x = self.head(x)
        return x

model = GCN(9, 64, 32)

if os.path.exists("model.pt"):
    print("Model loaded from checkpoint")
    model.load_state_dict(torch.load("model.pt"))

model = model.to(device)

# %%
import time

learning_rate = 0.001
max_iters = 200
lowest_mse_loss = np.inf

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
mseloss = torch.nn.MSELoss()
maeloss = torch.nn.L1Loss()

# Save the train_loss and val_loss during training
train_loss_list = []
val_loss_list = []

start_training_time = time.perf_counter() 
for iter in range(max_iters):
    # Training
    total_loss = 0
    for batch_data in train_loader:
        optimizer.zero_grad(set_to_none=True)
        out = model(batch_data.x, batch_data.edge_index, batch_data.batch)
        loss = mseloss(out,batch_data.y.reshape(-1,1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    # Evaluation
    model.eval()
    mse_loss = 0
    mae_loss = 0
    with torch.no_grad():
        for batch_data in val_loader:
            out = model(batch_data.x, batch_data.edge_index, batch_data.batch)
            mse_loss += mseloss(out,batch_data.y.reshape(-1,1)).item()
            mae_loss += maeloss(out,batch_data.y.reshape(-1,1)).item()

    if mse_loss < lowest_mse_loss:
        lowest_mse_loss = mse_loss
        torch.save(model.state_dict(),"model.pt")

    train_loss = total_loss/len(train_loader)
    val_loss = mse_loss/len(val_loader)
    print(f"Epoch {iter} | Loss train: {train_loss:.4f} | Loss val: {val_loss:.4f} | RMSE val: {(val_loss)**0.5:.4f} | MAE val: {mae_loss/len(val_loader):.4f}")
    train_loss_list.append(train_loss)
    val_loss_list.append(val_loss)
    model.train()
    
total_time = time.perf_counter() - start_training_time
print(f"Total time elapsed: {total_time:.4f} seconds.")
# Out:
# Epoch 0 | Loss train: 148439.8982 | Loss val: 59150.3071 | RMSE val: 243.2084 | MAE val: 219.2360
# Epoch 1 | Loss train: 17395.6073 | Loss val: 9863.9061 | RMSE val: 99.3172 | MAE val: 82.5932
# Epoch 2 | Loss train: 9972.9252 | Loss val: 9083.1551 | RMSE val: 95.3056 | MAE val: 79.0597
# Epoch 3 | Loss train: 9169.1203 | Loss val: 8327.2830 | RMSE val: 91.2539 | MAE val: 75.4139
# Epoch 4 | Loss train: 8404.3700 | Loss val: 7548.6417 | RMSE val: 86.8829 | MAE val: 71.4920
# Epoch 5 | Loss train: 7641.3865 | Loss val: 6862.8847 | RMSE val: 82.8425 | MAE val: 67.7579
# Epoch 6 | Loss train: 7007.9287 | Loss val: 6272.9573 | RMSE val: 79.2020 | MAE val: 64.6226
# Epoch 7 | Loss train: 6447.6182 | Loss val: 5793.7642 | RMSE val: 76.1168 | MAE val: 62.0913
# Epoch 8 | Loss train: 6017.7277 | Loss val: 5449.1024 | RMSE val: 73.8180 | MAE val: 60.0841
# Epoch 9 | Loss train: 5763.6649 | Loss val: 5227.7435 | RMSE val: 72.3031 | MAE val: 58.5238
# Epoch 10 | Loss train: 5581.1517 | Loss val: 5071.8796 | RMSE val: 71.2171 | MAE val: 57.3702
# Epoch 11 | Loss train: 5515.1433 | Loss val: 4998.3396 | RMSE val: 70.6989 | MAE val: 56.8108
# Epoch 12 | Loss train: 5406.2055 | Loss val: 4960.6667 | RMSE val: 70.4320 | MAE val: 56.5050
# Epoch 13 | Loss train: 5362.7777 | Loss val: 4913.7813 | RMSE val: 70.0984 | MAE val: 56.1297
# Epoch 14 | Loss train: 5345.5867 | Loss val: 4886.1813 | RMSE val: 69.9012 | MAE val: 55.9855
# Epoch 15 | Loss train: 5289.6832 | Loss val: 4833.7992 | RMSE val: 69.5255 | MAE val: 55.6557
# Epoch 16 | Loss train: 5274.4160 | Loss val: 4803.9329 | RMSE val: 69.3104 | MAE val: 55.4669
# Epoch 17 | Loss train: 5269.2658 | Loss val: 4777.5122 | RMSE val: 69.1196 | MAE val: 55.3044
# Epoch 18 | Loss train: 5215.2982 | Loss val: 4752.7816 | RMSE val: 68.9404 | MAE val: 55.1573
# Epoch 19 | Loss train: 5186.0191 | Loss val: 4735.7840 | RMSE val: 68.8170 | MAE val: 55.0022
# Epoch 20 | Loss train: 5211.1237 | Loss val: 4720.2192 | RMSE val: 68.7039 | MAE val: 55.0060
# Epoch 21 | Loss train: 5144.0046 | Loss val: 4688.9785 | RMSE val: 68.4761 | MAE val: 54.7278
# Epoch 22 | Loss train: 5134.3127 | Loss val: 4666.4612 | RMSE val: 68.3115 | MAE val: 54.6838
# Epoch 23 | Loss train: 5105.2095 | Loss val: 4651.2875 | RMSE val: 68.2003 | MAE val: 54.6205
# Epoch 24 | Loss train: 5137.6161 | Loss val: 4644.0353 | RMSE val: 68.1472 | MAE val: 54.6085
# Epoch 25 | Loss train: 5085.6913 | Loss val: 4601.1282 | RMSE val: 67.8316 | MAE val: 54.2793
# Epoch 26 | Loss train: 5055.2451 | Loss val: 4586.1934 | RMSE val: 67.7214 | MAE val: 54.1468
# Epoch 27 | Loss train: 5065.7027 | Loss val: 4569.2917 | RMSE val: 67.5965 | MAE val: 54.1511
# Epoch 28 | Loss train: 5014.2452 | Loss val: 4549.2145 | RMSE val: 67.4479 | MAE val: 54.0278
# Epoch 29 | Loss train: 5000.1105 | Loss val: 4567.4926 | RMSE val: 67.5832 | MAE val: 54.2275
# Epoch 30 | Loss train: 5013.8364 | Loss val: 4535.9188 | RMSE val: 67.3492 | MAE val: 53.8014
# Epoch 31 | Loss train: 4976.2173 | Loss val: 4516.7386 | RMSE val: 67.2067 | MAE val: 53.9193
# Epoch 32 | Loss train: 4987.2693 | Loss val: 4480.5783 | RMSE val: 66.9371 | MAE val: 53.6434
# Epoch 33 | Loss train: 4934.9729 | Loss val: 4463.9403 | RMSE val: 66.8127 | MAE val: 53.5507
# Epoch 34 | Loss train: 4951.9936 | Loss val: 4450.0358 | RMSE val: 66.7086 | MAE val: 53.4887
# Epoch 35 | Loss train: 4905.6896 | Loss val: 4463.9940 | RMSE val: 66.8131 | MAE val: 53.3688
# Epoch 36 | Loss train: 4904.3826 | Loss val: 4431.3168 | RMSE val: 66.5681 | MAE val: 53.4324
# Epoch 37 | Loss train: 4878.5417 | Loss val: 4424.7651 | RMSE val: 66.5189 | MAE val: 53.4172
# Epoch 38 | Loss train: 4858.9062 | Loss val: 4394.8137 | RMSE val: 66.2934 | MAE val: 53.2052
# Epoch 39 | Loss train: 4833.1169 | Loss val: 4379.6226 | RMSE val: 66.1787 | MAE val: 52.9654
# Epoch 40 | Loss train: 4848.5053 | Loss val: 4370.5431 | RMSE val: 66.1101 | MAE val: 53.0915
# Epoch 41 | Loss train: 4842.9235 | Loss val: 4346.7618 | RMSE val: 65.9300 | MAE val: 52.8158
# Epoch 42 | Loss train: 4823.2761 | Loss val: 4332.2065 | RMSE val: 65.8195 | MAE val: 52.7703
# Epoch 43 | Loss train: 4798.8054 | Loss val: 4327.7323 | RMSE val: 65.7855 | MAE val: 52.6497
# Epoch 44 | Loss train: 4785.0405 | Loss val: 4308.0894 | RMSE val: 65.6360 | MAE val: 52.6089
# Epoch 45 | Loss train: 4793.2552 | Loss val: 4297.4172 | RMSE val: 65.5547 | MAE val: 52.6173
# Epoch 46 | Loss train: 4781.0405 | Loss val: 4293.4696 | RMSE val: 65.5246 | MAE val: 52.6325
# Epoch 47 | Loss train: 4779.3673 | Loss val: 4268.6243 | RMSE val: 65.3347 | MAE val: 52.3768
# Epoch 48 | Loss train: 4779.7148 | Loss val: 4260.9006 | RMSE val: 65.2756 | MAE val: 52.2702
# Epoch 49 | Loss train: 4733.3739 | Loss val: 4247.9840 | RMSE val: 65.1766 | MAE val: 52.2868
# Epoch 50 | Loss train: 4721.0744 | Loss val: 4377.2952 | RMSE val: 66.1611 | MAE val: 53.3943
# Epoch 51 | Loss train: 4717.6103 | Loss val: 4245.8778 | RMSE val: 65.1604 | MAE val: 52.0818
# Epoch 52 | Loss train: 4725.2138 | Loss val: 4243.8813 | RMSE val: 65.1451 | MAE val: 52.4306
# Epoch 53 | Loss train: 4711.2996 | Loss val: 4220.2653 | RMSE val: 64.9636 | MAE val: 52.2325
# Epoch 54 | Loss train: 4674.8206 | Loss val: 4258.1686 | RMSE val: 65.2546 | MAE val: 52.0817
# Epoch 55 | Loss train: 4692.2957 | Loss val: 4185.0376 | RMSE val: 64.6919 | MAE val: 51.8510
# Epoch 56 | Loss train: 4665.8203 | Loss val: 4226.3594 | RMSE val: 65.0105 | MAE val: 52.3967
# Epoch 57 | Loss train: 4654.2446 | Loss val: 4221.8545 | RMSE val: 64.9758 | MAE val: 52.3754
# Epoch 58 | Loss train: 4650.6330 | Loss val: 4158.0679 | RMSE val: 64.4831 | MAE val: 51.6680
# Epoch 59 | Loss train: 4635.6306 | Loss val: 4178.8863 | RMSE val: 64.6443 | MAE val: 52.0582
# Epoch 60 | Loss train: 4632.0348 | Loss val: 4143.0988 | RMSE val: 64.3669 | MAE val: 51.6899
# Epoch 61 | Loss train: 4626.9290 | Loss val: 4129.1139 | RMSE val: 64.2582 | MAE val: 51.5402
# Epoch 62 | Loss train: 4633.6330 | Loss val: 4165.4317 | RMSE val: 64.5402 | MAE val: 51.5046
# Epoch 63 | Loss train: 4593.2226 | Loss val: 4109.5486 | RMSE val: 64.1058 | MAE val: 51.3959
# Epoch 64 | Loss train: 4606.8362 | Loss val: 4108.4658 | RMSE val: 64.0973 | MAE val: 51.4750
# Epoch 65 | Loss train: 4614.1095 | Loss val: 4104.2334 | RMSE val: 64.0643 | MAE val: 51.2568
# Epoch 66 | Loss train: 4593.6904 | Loss val: 4229.1117 | RMSE val: 65.0316 | MAE val: 52.5492
# Epoch 67 | Loss train: 4587.1715 | Loss val: 4081.2713 | RMSE val: 63.8848 | MAE val: 51.1397
# Epoch 68 | Loss train: 4560.6164 | Loss val: 4072.7907 | RMSE val: 63.8184 | MAE val: 51.0734
# Epoch 69 | Loss train: 4551.3441 | Loss val: 4104.0881 | RMSE val: 64.0632 | MAE val: 51.5984
# Epoch 70 | Loss train: 4556.0211 | Loss val: 4079.6597 | RMSE val: 63.8722 | MAE val: 50.9742
# Epoch 71 | Loss train: 4564.7336 | Loss val: 4086.8912 | RMSE val: 63.9288 | MAE val: 50.9627
# Epoch 72 | Loss train: 4543.1778 | Loss val: 4041.3301 | RMSE val: 63.5715 | MAE val: 50.9452
# Epoch 73 | Loss train: 4530.1762 | Loss val: 4037.6509 | RMSE val: 63.5425 | MAE val: 50.8554
# Epoch 74 | Loss train: 4533.3923 | Loss val: 4079.8624 | RMSE val: 63.8738 | MAE val: 51.4915
# Epoch 75 | Loss train: 4542.4562 | Loss val: 4026.3160 | RMSE val: 63.4533 | MAE val: 50.9367
# Epoch 76 | Loss train: 4543.8943 | Loss val: 4020.0608 | RMSE val: 63.4039 | MAE val: 50.9011
# Epoch 77 | Loss train: 4518.6764 | Loss val: 4033.9667 | RMSE val: 63.5135 | MAE val: 51.1275
# Epoch 78 | Loss train: 4508.9612 | Loss val: 4071.5803 | RMSE val: 63.8089 | MAE val: 51.4782
# Epoch 79 | Loss train: 4499.3116 | Loss val: 4006.8067 | RMSE val: 63.2993 | MAE val: 50.5256
# Epoch 80 | Loss train: 4470.3537 | Loss val: 3996.1930 | RMSE val: 63.2154 | MAE val: 50.4872
# Epoch 81 | Loss train: 4459.9444 | Loss val: 3986.7722 | RMSE val: 63.1409 | MAE val: 50.4417
# Epoch 82 | Loss train: 4453.2903 | Loss val: 3987.8094 | RMSE val: 63.1491 | MAE val: 50.4298
# Epoch 83 | Loss train: 4466.0027 | Loss val: 3973.4670 | RMSE val: 63.0354 | MAE val: 50.6671
# Epoch 84 | Loss train: 4423.7764 | Loss val: 3973.8770 | RMSE val: 63.0387 | MAE val: 50.7243
# Epoch 85 | Loss train: 4425.6043 | Loss val: 4017.5175 | RMSE val: 63.3839 | MAE val: 51.1339
# Epoch 86 | Loss train: 4423.0057 | Loss val: 3939.6959 | RMSE val: 62.7670 | MAE val: 50.2851
# Epoch 87 | Loss train: 4393.9535 | Loss val: 3955.4667 | RMSE val: 62.8925 | MAE val: 50.6055
# Epoch 88 | Loss train: 4377.9071 | Loss val: 3924.5677 | RMSE val: 62.6464 | MAE val: 50.1175
# Epoch 89 | Loss train: 4370.2521 | Loss val: 3924.0310 | RMSE val: 62.6421 | MAE val: 50.3505
# Epoch 90 | Loss train: 4372.9214 | Loss val: 3904.9303 | RMSE val: 62.4894 | MAE val: 50.1188
# Epoch 91 | Loss train: 4419.6215 | Loss val: 3889.6734 | RMSE val: 62.3672 | MAE val: 49.9176
# Epoch 92 | Loss train: 4338.6871 | Loss val: 3894.7389 | RMSE val: 62.4078 | MAE val: 49.7944
# Epoch 93 | Loss train: 4329.8930 | Loss val: 3875.6032 | RMSE val: 62.2543 | MAE val: 49.7739
# Epoch 94 | Loss train: 4324.6013 | Loss val: 3870.4067 | RMSE val: 62.2126 | MAE val: 49.7477
# Epoch 95 | Loss train: 4327.2586 | Loss val: 3859.2460 | RMSE val: 62.1228 | MAE val: 49.6320
# Epoch 96 | Loss train: 4334.7545 | Loss val: 3870.5104 | RMSE val: 62.2134 | MAE val: 49.9672
# Epoch 97 | Loss train: 4304.5965 | Loss val: 3892.6506 | RMSE val: 62.3911 | MAE val: 49.4841
# Epoch 98 | Loss train: 4296.7093 | Loss val: 3840.0811 | RMSE val: 61.9684 | MAE val: 49.6197
# Epoch 99 | Loss train: 4309.1253 | Loss val: 3832.5535 | RMSE val: 61.9076 | MAE val: 49.5687
# Epoch 100 | Loss train: 4268.0008 | Loss val: 3830.4693 | RMSE val: 61.8908 | MAE val: 49.3491
# Epoch 101 | Loss train: 4275.5960 | Loss val: 3844.4176 | RMSE val: 62.0034 | MAE val: 49.8610
# Epoch 102 | Loss train: 4263.0500 | Loss val: 3833.5536 | RMSE val: 61.9157 | MAE val: 49.7473
# Epoch 103 | Loss train: 4248.6104 | Loss val: 3827.1719 | RMSE val: 61.8641 | MAE val: 49.6967
# Epoch 104 | Loss train: 4236.1676 | Loss val: 3811.7081 | RMSE val: 61.7390 | MAE val: 49.5681
# Epoch 105 | Loss train: 4243.4006 | Loss val: 3807.7724 | RMSE val: 61.7072 | MAE val: 49.5504
# Epoch 106 | Loss train: 4229.6551 | Loss val: 3785.9900 | RMSE val: 61.5304 | MAE val: 49.1369
# Epoch 107 | Loss train: 4214.8675 | Loss val: 3776.4517 | RMSE val: 61.4528 | MAE val: 49.1292
# Epoch 108 | Loss train: 4200.9256 | Loss val: 3771.4673 | RMSE val: 61.4123 | MAE val: 49.2044
# Epoch 109 | Loss train: 4208.2204 | Loss val: 3759.5244 | RMSE val: 61.3150 | MAE val: 49.0840
# Epoch 110 | Loss train: 4209.4226 | Loss val: 3749.5735 | RMSE val: 61.2338 | MAE val: 48.9345
# Epoch 111 | Loss train: 4191.8738 | Loss val: 3761.6591 | RMSE val: 61.3324 | MAE val: 48.7445
# Epoch 112 | Loss train: 4188.7530 | Loss val: 3752.2595 | RMSE val: 61.2557 | MAE val: 48.7758
# Epoch 113 | Loss train: 4156.0723 | Loss val: 3741.1326 | RMSE val: 61.1648 | MAE val: 48.7692
# Epoch 114 | Loss train: 4163.4733 | Loss val: 3749.5166 | RMSE val: 61.2333 | MAE val: 48.5997
# Epoch 115 | Loss train: 4166.0048 | Loss val: 3782.7483 | RMSE val: 61.5041 | MAE val: 49.5639
# Epoch 116 | Loss train: 4151.7185 | Loss val: 3722.3575 | RMSE val: 61.0111 | MAE val: 48.4826
# Epoch 117 | Loss train: 4155.9362 | Loss val: 3705.4157 | RMSE val: 60.8721 | MAE val: 48.5367
# Epoch 118 | Loss train: 4158.3411 | Loss val: 3715.3960 | RMSE val: 60.9540 | MAE val: 48.4681
# Epoch 119 | Loss train: 4129.4052 | Loss val: 3760.8342 | RMSE val: 61.3256 | MAE val: 49.4269
# Epoch 120 | Loss train: 4124.9535 | Loss val: 3696.5442 | RMSE val: 60.7992 | MAE val: 48.6653
# Epoch 121 | Loss train: 4122.0466 | Loss val: 3748.7303 | RMSE val: 61.2269 | MAE val: 49.3374
# Epoch 122 | Loss train: 4101.9567 | Loss val: 3687.5806 | RMSE val: 60.7255 | MAE val: 48.4094
# Epoch 123 | Loss train: 4113.4577 | Loss val: 3675.3083 | RMSE val: 60.6243 | MAE val: 48.3409
# Epoch 124 | Loss train: 4105.7032 | Loss val: 3710.8433 | RMSE val: 60.9167 | MAE val: 48.9644
# Epoch 125 | Loss train: 4130.9784 | Loss val: 3688.1255 | RMSE val: 60.7299 | MAE val: 48.7054
# Epoch 126 | Loss train: 4075.7503 | Loss val: 3675.4749 | RMSE val: 60.6257 | MAE val: 48.1990
# Epoch 127 | Loss train: 4093.2784 | Loss val: 3661.0113 | RMSE val: 60.5063 | MAE val: 48.2119
# Epoch 128 | Loss train: 4072.0097 | Loss val: 3666.3880 | RMSE val: 60.5507 | MAE val: 48.1455
# Epoch 129 | Loss train: 4074.1706 | Loss val: 3654.0017 | RMSE val: 60.4483 | MAE val: 48.2482
# Epoch 130 | Loss train: 4074.6228 | Loss val: 3652.3073 | RMSE val: 60.4343 | MAE val: 48.0769
# Epoch 131 | Loss train: 4065.2510 | Loss val: 3652.4674 | RMSE val: 60.4356 | MAE val: 48.1839
# Epoch 132 | Loss train: 4048.3566 | Loss val: 3639.6015 | RMSE val: 60.3291 | MAE val: 48.0860
# Epoch 133 | Loss train: 4076.0437 | Loss val: 3639.0494 | RMSE val: 60.3245 | MAE val: 48.0174
# Epoch 134 | Loss train: 4129.3821 | Loss val: 3638.1638 | RMSE val: 60.3172 | MAE val: 48.0898
# Epoch 135 | Loss train: 4047.5157 | Loss val: 3632.8448 | RMSE val: 60.2731 | MAE val: 48.1445
# Epoch 136 | Loss train: 4024.4276 | Loss val: 3643.2239 | RMSE val: 60.3591 | MAE val: 47.9730
# Epoch 137 | Loss train: 4064.1254 | Loss val: 3652.7083 | RMSE val: 60.4376 | MAE val: 47.9071
# Epoch 138 | Loss train: 4032.3502 | Loss val: 3635.2644 | RMSE val: 60.2932 | MAE val: 48.3241
# Epoch 139 | Loss train: 4033.4296 | Loss val: 3621.7467 | RMSE val: 60.1810 | MAE val: 48.0726
# Epoch 140 | Loss train: 4026.9924 | Loss val: 3620.1533 | RMSE val: 60.1677 | MAE val: 47.9007
# Epoch 141 | Loss train: 4064.1054 | Loss val: 3627.8206 | RMSE val: 60.2314 | MAE val: 48.2509
# Epoch 142 | Loss train: 4003.0534 | Loss val: 3628.7654 | RMSE val: 60.2392 | MAE val: 48.2992
# Epoch 143 | Loss train: 4022.1433 | Loss val: 3609.8140 | RMSE val: 60.0817 | MAE val: 47.9258
# Epoch 144 | Loss train: 4015.7079 | Loss val: 3613.6259 | RMSE val: 60.1134 | MAE val: 47.8269
# Epoch 145 | Loss train: 4029.5364 | Loss val: 3610.7485 | RMSE val: 60.0895 | MAE val: 47.7063
# Epoch 146 | Loss train: 4000.3978 | Loss val: 3604.0880 | RMSE val: 60.0341 | MAE val: 47.9570
# Epoch 147 | Loss train: 3986.8651 | Loss val: 3641.4117 | RMSE val: 60.3441 | MAE val: 47.7227
# Epoch 148 | Loss train: 3984.9447 | Loss val: 3628.4168 | RMSE val: 60.2363 | MAE val: 47.6736
# Epoch 149 | Loss train: 3991.6962 | Loss val: 3595.9740 | RMSE val: 59.9664 | MAE val: 47.8955
# Epoch 150 | Loss train: 4001.6778 | Loss val: 3636.9777 | RMSE val: 60.3074 | MAE val: 48.4693
# Epoch 151 | Loss train: 4000.2510 | Loss val: 3687.1458 | RMSE val: 60.7219 | MAE val: 47.7894
# Epoch 152 | Loss train: 3986.8232 | Loss val: 3591.1156 | RMSE val: 59.9259 | MAE val: 47.6125
# Epoch 153 | Loss train: 3991.6497 | Loss val: 3583.6694 | RMSE val: 59.8638 | MAE val: 47.5692
# Epoch 154 | Loss train: 3990.0005 | Loss val: 3595.2188 | RMSE val: 59.9601 | MAE val: 47.9951
# Epoch 155 | Loss train: 3973.8419 | Loss val: 3587.2869 | RMSE val: 59.8940 | MAE val: 47.9103
# Epoch 156 | Loss train: 3979.6222 | Loss val: 3612.2657 | RMSE val: 60.1021 | MAE val: 48.2885
# Epoch 157 | Loss train: 3987.8408 | Loss val: 3677.3559 | RMSE val: 60.6412 | MAE val: 47.8048
# Epoch 158 | Loss train: 3984.8940 | Loss val: 3592.3299 | RMSE val: 59.9360 | MAE val: 47.5175
# Epoch 159 | Loss train: 3982.3989 | Loss val: 3571.1828 | RMSE val: 59.7594 | MAE val: 47.4438
# Epoch 160 | Loss train: 3955.8366 | Loss val: 3576.1889 | RMSE val: 59.8012 | MAE val: 47.8356
# Epoch 161 | Loss train: 3985.3891 | Loss val: 3573.9384 | RMSE val: 59.7824 | MAE val: 47.4879
# Epoch 162 | Loss train: 3972.7128 | Loss val: 3649.0633 | RMSE val: 60.4075 | MAE val: 47.5180
# Epoch 163 | Loss train: 3967.2692 | Loss val: 3578.1763 | RMSE val: 59.8179 | MAE val: 47.9227
# Epoch 164 | Loss train: 3945.2531 | Loss val: 3612.0297 | RMSE val: 60.1002 | MAE val: 48.3198
# Epoch 165 | Loss train: 3940.2082 | Loss val: 3573.8998 | RMSE val: 59.7821 | MAE val: 47.3143
# Epoch 166 | Loss train: 3962.2728 | Loss val: 3599.9575 | RMSE val: 59.9996 | MAE val: 48.2106
# Epoch 167 | Loss train: 3942.3214 | Loss val: 3608.5036 | RMSE val: 60.0708 | MAE val: 47.3876
# Epoch 168 | Loss train: 3938.0732 | Loss val: 3559.9096 | RMSE val: 59.6650 | MAE val: 47.4327
# Epoch 169 | Loss train: 3979.5986 | Loss val: 3551.1109 | RMSE val: 59.5912 | MAE val: 47.4184
# Epoch 170 | Loss train: 3936.5938 | Loss val: 3565.5729 | RMSE val: 59.7124 | MAE val: 47.2405
# Epoch 171 | Loss train: 3928.2955 | Loss val: 3551.3710 | RMSE val: 59.5934 | MAE val: 47.5791
# Epoch 172 | Loss train: 3920.0654 | Loss val: 3548.7723 | RMSE val: 59.5716 | MAE val: 47.2732
# Epoch 173 | Loss train: 3930.8944 | Loss val: 3555.3795 | RMSE val: 59.6270 | MAE val: 47.2205
# Epoch 174 | Loss train: 3920.7093 | Loss val: 3546.7044 | RMSE val: 59.5542 | MAE val: 47.5305
# Epoch 175 | Loss train: 3936.2542 | Loss val: 3578.5367 | RMSE val: 59.8209 | MAE val: 48.0040
# Epoch 176 | Loss train: 3917.9648 | Loss val: 3543.1409 | RMSE val: 59.5243 | MAE val: 47.2382
# Epoch 177 | Loss train: 3922.0870 | Loss val: 3539.4606 | RMSE val: 59.4934 | MAE val: 47.2272
# Epoch 178 | Loss train: 3907.1970 | Loss val: 3552.5819 | RMSE val: 59.6035 | MAE val: 47.6908
# Epoch 179 | Loss train: 3952.8424 | Loss val: 3534.3147 | RMSE val: 59.4501 | MAE val: 47.3467
# Epoch 180 | Loss train: 3906.5248 | Loss val: 3535.9501 | RMSE val: 59.4639 | MAE val: 47.2752
# Epoch 181 | Loss train: 3892.2036 | Loss val: 3530.7921 | RMSE val: 59.4205 | MAE val: 47.3047
# Epoch 182 | Loss train: 3903.1473 | Loss val: 3532.9720 | RMSE val: 59.4388 | MAE val: 47.3979
# Epoch 183 | Loss train: 3923.3772 | Loss val: 3554.0521 | RMSE val: 59.6159 | MAE val: 47.7418
# Epoch 184 | Loss train: 3910.2838 | Loss val: 3529.8507 | RMSE val: 59.4125 | MAE val: 47.1851
# Epoch 185 | Loss train: 3894.1680 | Loss val: 3690.7882 | RMSE val: 60.7519 | MAE val: 47.5865
# Epoch 186 | Loss train: 3936.9222 | Loss val: 3548.8308 | RMSE val: 59.5721 | MAE val: 47.6477
# Epoch 187 | Loss train: 3893.5559 | Loss val: 3542.2229 | RMSE val: 59.5166 | MAE val: 47.1129
# Epoch 188 | Loss train: 3892.3248 | Loss val: 3606.7116 | RMSE val: 60.0559 | MAE val: 48.2842
# Epoch 189 | Loss train: 3917.9692 | Loss val: 3577.4054 | RMSE val: 59.8114 | MAE val: 48.0169
# Epoch 190 | Loss train: 3878.3179 | Loss val: 3520.8457 | RMSE val: 59.3367 | MAE val: 47.1549
# Epoch 191 | Loss train: 3903.8735 | Loss val: 3519.1761 | RMSE val: 59.3226 | MAE val: 47.1996
# Epoch 192 | Loss train: 3902.0097 | Loss val: 3588.2437 | RMSE val: 59.9020 | MAE val: 48.1449
# Epoch 193 | Loss train: 3880.9791 | Loss val: 3530.8048 | RMSE val: 59.4206 | MAE val: 47.0365
# Epoch 194 | Loss train: 3885.8758 | Loss val: 3518.1459 | RMSE val: 59.3140 | MAE val: 47.2933
# Epoch 195 | Loss train: 3882.0051 | Loss val: 3518.5145 | RMSE val: 59.3171 | MAE val: 47.3152
# Epoch 196 | Loss train: 3868.1379 | Loss val: 3516.0309 | RMSE val: 59.2961 | MAE val: 47.2889
# Epoch 197 | Loss train: 3886.2124 | Loss val: 3520.5106 | RMSE val: 59.3339 | MAE val: 47.3857
# Epoch 198 | Loss train: 3890.4850 | Loss val: 3513.1368 | RMSE val: 59.2717 | MAE val: 47.2542
# Epoch 199 | Loss train: 3877.0889 | Loss val: 3552.8202 | RMSE val: 59.6055 | MAE val: 47.1010
# Total time elapsed: 276.0601 seconds.

# %%
import matplotlib.pyplot as plt
start_iter = 50
fig, ax = plt.subplots(layout='constrained')
x = np.arange(start_iter,max_iters,1)
color = "blue"
ax.plot(x, train_loss_list[start_iter:], color = color, label = 'Train loss')
color = "red"
ax.plot(x, val_loss_list[start_iter:], color = color, label = 'Val loss')
ax.set_xlabel("Number of epochs")
ax.set_ylabel("MSE loss")
ax.legend()
plt.show()

# %% [markdown]
# Add a evaluation on the test set

# %%
model = GCN(9,64,32)
model.load_state_dict(torch.load("model.pt"))

model.eval()
mse_loss = 0
mae_loss = 0
with torch.no_grad():
    for batch_data in test_loader:
        out = model(batch_data.x, batch_data.edge_index, batch_data.batch)
        mse_loss += mseloss(out,batch_data.y.reshape(-1,1)).item()
        mae_loss += maeloss(out,batch_data.y.reshape(-1,1)).item()

print(f"RMSE test: {(mse_loss/len(test_loader))**0.5:.4f} | MAE test: {mae_loss/len(test_loader):.4f}")
# Out:
# RMSE test: 57.1118 | MAE test: 45.0390

# %%
print(f"Total number of parameters : {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
# Out:
# Total number of parameters : 2753
